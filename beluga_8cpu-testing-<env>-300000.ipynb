# %% [markdown]
# # Observing steps per second

# %%
import wandb
import json
import os
import pickle
from collections import defaultdict
import pandas as pd

# %%
# glob.glob("runs/**/events.out.tfevents*")

# %%
wandb.login()

# Define where to store the cache files
cache_dir = "./wandb_cache/"
if not os.path.exists(cache_dir):
    os.makedirs(cache_dir)
# Out:
# wandb: Currently logged in as: adrian-orenstein (the-orbital-mind). Use `wandb login --relogin` to force relogin

# %%
project_name = "beluga_8cpu-testing-lunarlander-v2-300000"
entity_name = "the-orbital-mind"  # Optionalimport pandas as pd

# %%
# Fetch runs
api = wandb.Api()
runs = api.runs(f"{entity_name}/{project_name}")

# Check if there are any runs available
if runs:
    # Fetch history of the first run
    first_run = runs[0]
    history_df = first_run.history()

    # Print available keys in the history
    print("Available keys in the history:")
    for key in history_df.columns:
        print(key)
else:
    print("No runs found.")
# Out:
# Available keys in the history:
# environment/ratio
# _step
# environment/num_repeat_actions
# agent/step_sps
# _runtime
# environment/agent_response_time
# global_step
# _timestamp
# agent/step_dt
# charts/episodic_length
# charts/episodic_return
# agent_losses/td_loss
# agent_losses/q_values
# dqn/update_target_network

# %%
import os
import pickle
import wandb
from concurrent.futures import ThreadPoolExecutor

PROJECTS = [
    "beluga_8cpu-testing-lunarlander-v2-300000",
    "beluga_8cpu-testing-acrobot-v1-300000",
    "beluga_8cpu-testing-mountaincar-v0-300000",
    "beluga_8cpu-testing-cartpole-v1-300000",
]

for project_name in PROJECTS:
    api = wandb.Api(timeout=20)
    runs = api.runs(f"{entity_name}/{project_name}")
    
    # Define where to store the cache files
    cache_dir = "./wandb_cache/"
    if not os.path.exists(cache_dir):
        os.makedirs(cache_dir)
    
    def process_run(job):
        (i, run) = job
    
        cache_path = os.path.join(cache_dir, f"{run.id}.pkl")
    
        # Check if we have cached data
        if not os.path.exists(cache_path):
            df = run.history()
            with open(cache_path, 'wb') as file:
                pickle.dump(df, file)
            print(f"Data cached for run: {run.id}, {i/len(runs):0.2}")
        # else:
        #     print(f"Already cached run: {run.id}, {i/len(runs):0.2}")
    
    # Use ThreadPoolExecutor to handle the runs in parallel
    with ThreadPoolExecutor(max_workers=8) as executor:
        executor.map(process_run, (enumerate(runs)))
# Out:
# Data cached for run: tnfhwg13, 0.0054
# Data cached for run: aofrrlmu, 0.0
# Data cached for run: 0uv7d7iz, 0.011
# Data cached for run: c9phhoud, 0.022
# Data cached for run: htg7nbmp, 0.038
# Data cached for run: 7bxz561k, 0.016
# Data cached for run: y5hjgko8, 0.043
# Data cached for run: di0c1bsn, 0.032
# Data cached for run: x98jzqyt, 0.049
# Data cached for run: z761ptct, 0.059
# Data cached for run: m5eue7nr, 0.027
# Data cached for run: ksqtqbya, 0.054
# Data cached for run: fk6ezf7c, 0.07
# Data cached for run: nstq2fln, 0.065
# Data cached for run: bzc9jltj, 0.076
# Data cached for run: 7ttfiuip, 0.081
# Data cached for run: ro31cqmb, 0.092
# Data cached for run: bjawfn9p, 0.097
# Data cached for run: qjdxf8fl, 0.086
# Data cached for run: aslwrz7n, 0.1
# Data cached for run: zru2eb6t, 0.11
# Data cached for run: 7p91n8h8, 0.11
# Data cached for run: 66qd9jbv, 0.12
# Data cached for run: biuwcb4m, 0.13
# Data cached for run: 1i82yc1d, 0.14
# Data cached for run: 2x5a3gv9, 0.14
# Data cached for run: cozvznnt, 0.15
# Data cached for run: os0kmztd, 0.15
# Data cached for run: wx1w1q98, 0.12
# Data cached for run: ry6v1i6l, 0.16
# Data cached for run: 8dny5qti, 0.16
# Data cached for run: pujpac4d, 0.17
# Data cached for run: wiitcy8j, 0.17
# Data cached for run: nq0lbu4c, 0.18
# Data cached for run: sjqlajej, 0.19
# Data cached for run: hj2608j5, 0.18
# Data cached for run: rtb3roi1, 0.2
# Data cached for run: ozi73chy, 0.19
# Data cached for run: g9y31hiu, 0.22
# Data cached for run: dy28psg3, 0.22
# Data cached for run: 7xox85sa, 0.21
# Data cached for run: 8ev1491o, 0.21
# Data cached for run: a14pc8dw, 0.23
# Data cached for run: dq0cfenf, 0.23
# Data cached for run: tyna4ang, 0.24
# Data cached for run: 3m425iy6, 0.25
# Data cached for run: sxk4n93z, 0.24
# Data cached for run: v9mbayo5, 0.25
# Data cached for run: dlfevwhg, 0.27
# Data cached for run: icyzjzr1, 0.26
# Data cached for run: 9t7jw2do, 0.28
# Data cached for run: nsncffy1, 0.26
# Data cached for run: hsacj35l, 0.3
# Data cached for run: 6i8rb3e8, 0.29
# Data cached for run: vxdqqzi2, 0.28
# Data cached for run: uuqymfg6, 0.31
# Data cached for run: 8geddne2, 0.3
# Data cached for run: qmxz6uc1, 0.29
# Data cached for run: iky973i4, 0.31
# Data cached for run: ywgrlqkf, 0.32
# Data cached for run: 87cjbmz1, 0.33
# Data cached for run: 9k0ndpa4, 0.32
# Data cached for run: duxeq51c, 0.34
# Data cached for run: 3msve7xv, 0.35
# Data cached for run: q77tlfgv, 0.34
# Data cached for run: jhlvoxj1, 0.36
# Data cached for run: c2yij8w4, 0.36
# Data cached for run: zv3zgspv, 0.35
# Data cached for run: dqhs1jwd, 0.37
# Data cached for run: zepjiyww, 0.4
# Data cached for run: xc86it25, 0.37
# Data cached for run: 2rbsl4wb, 0.38
# Data cached for run: htn1x86d, 0.39
# Data cached for run: tjneyamh, 0.38
# Data cached for run: 49orofu7, 0.41
# Data cached for run: 75l4sxq6, 0.41
# Data cached for run: awcahr85, 0.39
# Data cached for run: i6a0d41t, 0.42
# Data cached for run: to2myywj, 0.43
# Data cached for run: b5q1phv7, 0.42
# Data cached for run: ztfr8f2m, 0.45
# Data cached for run: srrbbyl5, 0.45
# Data cached for run: kg2p1oon, 0.44
# Data cached for run: emj3rrv3, 0.43
# Data cached for run: xos5unp6, 0.46
# Data cached for run: lhfop6g2, 0.44
# Data cached for run: pk5jotck, 0.47
# Data cached for run: 7ih00q7r, 0.46
# Data cached for run: q2q30qn5, 0.48
# Data cached for run: lc8iqcym, 0.48
# Data cached for run: cxgx8znf, 0.5
# Data cached for run: vuhcir87, 0.5
# Data cached for run: xdsg0bp2, 0.49
# Data cached for run: itzvtsei, 0.49
# Data cached for run: 7x087ayj, 0.51
# Data cached for run: 4iml31c4, 0.51
# Data cached for run: qkfug2w2, 0.52
# Data cached for run: 7zqbceek, 0.52
# Data cached for run: yqm7j143, 0.53
# Data cached for run: jax2hclu, 0.54
# Data cached for run: sop0824j, 0.54
# Data cached for run: dm9o2zom, 0.55
# Data cached for run: gsuizvhj, 0.55
# Data cached for run: kshtviby, 0.56
# Data cached for run: 0k4dj6cd, 0.57
# Data cached for run: uj9lmwwt, 0.56
# Data cached for run: dorxyxjx, 0.58
# Data cached for run: e137dgf8, 0.57
# Data cached for run: mqcp0ce7, 0.58
# Data cached for run: xjt9vcy2, 0.59
# Data cached for run: 0p572k4a, 0.59
# Data cached for run: b3fgzymm, 0.6
# Data cached for run: wa9tnefz, 0.61
# Data cached for run: 9um5xbtz, 0.62
# Data cached for run: f5csbmyg, 0.61
# Data cached for run: nakhpr1m, 0.63
# Data cached for run: qvllzy2d, 0.62
# Data cached for run: rafneeqs, 0.64
# Data cached for run: 8n69hcea, 0.64
# Data cached for run: z58otyll, 0.63
# Data cached for run: d1fp0zhu, 0.65
# Data cached for run: saqhqny6, 0.65
# Data cached for run: ugh8jdqm, 0.66
# Data cached for run: ptmqpk1w, 0.66
# Data cached for run: hleyjhdc, 0.68
# Data cached for run: p7w5tfcp, 0.67
# Data cached for run: h8bautpu, 0.68
# Data cached for run: blzc38tz, 0.69
# Data cached for run: 0xt2hgn8, 0.69
# Data cached for run: h0l174j7, 0.7
# Data cached for run: o5xldsmy, 0.71
# Data cached for run: hjusxoom, 0.7
# Data cached for run: y6ow88ok, 0.72
# Data cached for run: ggq9ptdt, 0.71
# Data cached for run: 1leyy2a8, 0.73
# Data cached for run: n7sc44nx, 0.74
# Data cached for run: x5ib5a0i, 0.75
# Data cached for run: hdryi2rc, 0.74
# Data cached for run: 6h1m1w3u, 0.72
# Data cached for run: uszpghh6, 0.75
# Data cached for run: g3xovf2u, 0.76
# Data cached for run: 74amrxg9, 0.76
# Data cached for run: 21ugxhsr, 0.77
# Data cached for run: dh6ainm3, 0.0
# Data cached for run: 0vrj66gj, 0.01
# Data cached for run: i0dhtssu, 0.005
# Data cached for run: 0t3fkhv9, 0.015
# Data cached for run: oqb54auj, 0.025
# Data cached for run: 8jtb74vg, 0.02
# Data cached for run: awwkukw0, 0.035
# Data cached for run: icq2z52s, 0.03
# Data cached for run: st7dkn6k, 0.055
# Data cached for run: wkd53ojm, 0.04
# Data cached for run: r4ugr2xp, 0.06
# Data cached for run: wn88rbx4, 0.05
# Data cached for run: punksmwb, 0.045
# Data cached for run: 7kwjpn5r, 0.065
# Data cached for run: 526pneqh, 0.07
# Data cached for run: v7985q2x, 0.075
# Data cached for run: e0ikcbhr, 0.085
# Data cached for run: dluiwyop, 0.08
# Data cached for run: avumrukd, 0.095
# Data cached for run: goihcl9u, 0.1
# Data cached for run: rdmspd38, 0.09
# Data cached for run: 90uujlca, 0.1
# Data cached for run: fwnjpqoh, 0.11
# Data cached for run: 6zdyzgyf, 0.12
# Data cached for run: aeou5pfm, 0.12
# Data cached for run: r9wy4lwn, 0.13
# Data cached for run: r708yx4y, 0.11
# Data cached for run: uad427q5, 0.13
# Data cached for run: cuukom5s, 0.14
# Data cached for run: s9w0lhhz, 0.15
# Data cached for run: s9dusj5f, 0.14
# Data cached for run: ef6cj35t, 0.16
# Data cached for run: uvpq5yov, 0.15
# Data cached for run: b5p2je50, 0.16
# Data cached for run: lpo1i1wl, 0.17
# Data cached for run: xkrb9t53, 0.17
# Data cached for run: 6gnxpicq, 0.18
# Data cached for run: 5geecz0j, 0.18
# Data cached for run: o6hvxe53, 0.19
# Data cached for run: 3n6oy4ef, 0.19
# Data cached for run: m3nez6vq, 0.2
# Data cached for run: vimfka57, 0.2
# Data cached for run: 330xe58a, 0.22
# Data cached for run: 67ph96f2, 0.22
# Data cached for run: a6svm3kh, 0.21
# Data cached for run: 3iivrbe5, 0.21
# Data cached for run: qgosnp8j, 0.23
# Data cached for run: noybcphn, 0.24
# Data cached for run: joiciw4n, 0.24
# Data cached for run: uajwd3uw, 0.23
# Data cached for run: 6bwihrbu, 0.25
# Data cached for run: rw53sbsv, 0.25
# Data cached for run: sllezlm3, 0.26
# Data cached for run: zkpll4rr, 0.26
# Data cached for run: znlr028v, 0.27
# Data cached for run: 7qqhs2gz, 0.28
# Data cached for run: va31k9tk, 0.29
# Data cached for run: 4e1nfsx1, 0.28
# Data cached for run: y7pzd815, 0.29
# Data cached for run: dj654qt9, 0.27
# Data cached for run: gmw51kuh, 0.31
# Data cached for run: 9612macq, 0.3
# Data cached for run: rt8751q0, 0.3
# Data cached for run: vhb3kh0d, 0.31
# Data cached for run: ce43jp3t, 0.33
# Data cached for run: njchfcvo, 0.32
# Data cached for run: 200smwa4, 0.33
# Data cached for run: wwqtsmcs, 0.34
# Data cached for run: lqrmbsgn, 0.32
# Data cached for run: n98u5dtb, 0.35
# Data cached for run: ufefk36h, 0.34
# Data cached for run: 528grpn4, 0.35
# Data cached for run: palcnxl4, 0.36
# Data cached for run: bajvjd8t, 0.36
# Data cached for run: 9ofxcdib, 0.37
# Data cached for run: bchg3mcl, 0.38
# Data cached for run: mxp9tyhq, 0.37
# Data cached for run: 83gdzfqk, 0.38
# Data cached for run: rr6pempt, 0.39
# Data cached for run: i1mefdmy, 0.39
# Data cached for run: h1xf7zum, 0.4
# Data cached for run: jsxx3er1, 0.41
# Data cached for run: qlz7die2, 0.4
# Data cached for run: 092shn9g, 0.42
# Data cached for run: wpbauvqi, 0.42
# Data cached for run: xb33culu, 0.41
# Data cached for run: xejy2sa7, 0.43
# Data cached for run: 3k7039ms, 0.43
# Data cached for run: d35kc49s, 0.44
# Data cached for run: qchw22yu, 0.45
# Data cached for run: wp6gg9u9, 0.46
# Data cached for run: mja5yts2, 0.45
# Data cached for run: svib5wcq, 0.46
# Data cached for run: nv3rx7np, 0.44
# Data cached for run: 9fhbmtlh, 0.47
# Data cached for run: d7sgoj2r, 0.47
# Data cached for run: v62cz8io, 0.48
# Data cached for run: jav5e54y, 0.48
# Data cached for run: 297wfg3a, 0.49
# Data cached for run: 24nlvkgb, 0.5
# Data cached for run: xtsmflbe, 0.49
# Data cached for run: j7r24xq5, 0.5
# Data cached for run: jjt6gyhr, 0.51
# Data cached for run: 1x77fxow, 0.51
# Data cached for run: vgp02ond, 0.52
# Data cached for run: 4cpmuhpf, 0.53
# Data cached for run: i5hko3td, 0.52
# Data cached for run: 4x6kusb8, 0.53
# Data cached for run: zq8j5hs9, 0.54
# Data cached for run: 6i6pzavs, 0.54
# Data cached for run: hih9062q, 0.55
# Data cached for run: wdi03s71, 0.56
# Data cached for run: 643fmh5e, 0.55
# Data cached for run: dwatc4ch, 0.56
# Data cached for run: atjha2z8, 0.57
# Data cached for run: vdlgt4e7, 0.58
# Data cached for run: leljiy2k, 0.57
# Data cached for run: hls9bmqr, 0.58
# Data cached for run: nr6wuykj, 0.59
# Data cached for run: ak4e0mes, 0.59
# Data cached for run: e4c141dk, 0.6
# Data cached for run: 48jwkiy6, 0.6
# Data cached for run: 9mj1984o, 0.61
# Data cached for run: b472teop, 0.62
# Data cached for run: tq31xm6v, 0.61
# Data cached for run: nd3y9uus, 0.62
# Data cached for run: mhku34xr, 0.63
# Data cached for run: 3x4cam5z, 0.64
# Data cached for run: cc4awztq, 0.64
# Data cached for run: i9x6duk9, 0.63
# Data cached for run: 40rxam93, 0.65
# Data cached for run: teiqeq1e, 0.66
# Data cached for run: srzyzfwo, 0.65
# Data cached for run: xx3wetr3, 0.66
# Data cached for run: cus067th, 0.67
# Data cached for run: u9u8lezg, 0.67
# Data cached for run: 2wp6win0, 0.68
# Data cached for run: 6zlmd0vn, 0.68
# Data cached for run: z597o5wh, 0.69
# Data cached for run: ulgftvxe, 0.69
# Data cached for run: m20dgzqw, 0.7
# Data cached for run: w4hmsxwp, 0.7
# Data cached for run: gspktbhi, 0.71
# Data cached for run: zpe2kz9o, 0.71
# Data cached for run: dkf02u1p, 0.72
# Data cached for run: 84esnibq, 0.73
# Data cached for run: 346wey1i, 0.74
# Data cached for run: xhonfero, 0.72
# Data cached for run: 3qq2wbz5, 0.73
# Data cached for run: p84ygiiy, 0.74
# Data cached for run: ofle9hw8, 0.75
# Data cached for run: yl2azn5l, 0.75
# Data cached for run: e29qvbtw, 0.025
# Data cached for run: j40mcr23, 0.017
# Data cached for run: 3wz8rqe6, 0.0
# Data cached for run: xkb6xsdg, 0.021
# Data cached for run: y2ynw6yl, 0.013
# Data cached for run: zz0pmsd5, 0.0042
# Data cached for run: c0hadhcx, 0.029
# Data cached for run: we8f27zq, 0.0084
# Data cached for run: xy283ype, 0.034
# Data cached for run: zz2xzk8i, 0.038
# Data cached for run: 7o5n9axt, 0.046
# Data cached for run: eplfy72q, 0.042
# Data cached for run: 6xmbwj32, 0.05
# Data cached for run: qdnjh85w, 0.055
# Data cached for run: fllos6g0, 0.059
# Data cached for run: frnzpf5h, 0.063
# Data cached for run: w2trnzi0, 0.071
# Data cached for run: 78q57tzw, 0.076
# Data cached for run: yte0pyg0, 0.067
# Data cached for run: 81w1lqa7, 0.088
# Data cached for run: 3kz7gh4d, 0.08
# Data cached for run: yuoo5xkk, 0.092
# Data cached for run: o5g5zssz, 0.097
# Data cached for run: 2nmadwmm, 0.084
# Data cached for run: d6w63tet, 0.11
# Data cached for run: oe3g748u, 0.1Data cached for run: z2alt19x, 0.11
#
# Data cached for run: lhongutx, 0.11
# Data cached for run: w3gqcsqk, 0.12
# Data cached for run: 2zvncn3a, 0.12
# Data cached for run: 5bnsx3zj, 0.13
# Data cached for run: j5iyx36i, 0.13
# Data cached for run: 0qk9fev0, 0.13
# Data cached for run: ygq58dr6, 0.14Data cached for run: 6l611w20, 0.14
#
# Data cached for run: 6g9zihi0, 0.15
# Data cached for run: x11c1vdw, 0.15
# Data cached for run: haza0dek, 0.16
# Data cached for run: y28ky94z, 0.16
# Data cached for run: nkhj92if, 0.16
# Data cached for run: ot9u5al1, 0.17
# Data cached for run: aw8tjlz5, 0.17
# Data cached for run: t6ezitog, 0.18
# Data cached for run: 0f23sfxg, 0.18
# Data cached for run: jxkag80g, 0.18
# Data cached for run: qcrn0wqe, 0.19
# Data cached for run: iuqtevso, 0.19
# Data cached for run: sawpdlrp, 0.2
# Data cached for run: 28cy08cx, 0.2
# Data cached for run: llkobkmb, 0.21
# Data cached for run: vfak9r5d, 0.21
# Data cached for run: nti2c404, 0.21
# Data cached for run: es15rayq, 0.22
# Data cached for run: 47lk9nqt, 0.23
# Data cached for run: 8jwqfaig, 0.22
# Data cached for run: 6mkrxzz3, 0.23
# Data cached for run: 1tynp8ho, 0.24
# Data cached for run: b5ia9hwn, 0.24
# Data cached for run: 6ppx3ozc, 0.24
# Data cached for run: cuwwk4sm, 0.25
# Data cached for run: xhlgu1q0, 0.25
# Data cached for run: xo98dy2r, 0.26
# Data cached for run: 9tvztjg1, 0.27
# Data cached for run: qwjxbg1g, 0.26
# Data cached for run: bnmtg00x, 0.26
# Data cached for run: iqja0jwk, 0.27
# Data cached for run: w0y6tqq1, 0.28
# Data cached for run: m44jipyh, 0.28
# Data cached for run: c8in0vvc, 0.29
# Data cached for run: 098vhm45, 0.29
# Data cached for run: i83g78nj, 0.29
# Data cached for run: ahn4jcx3, 0.3
# Data cached for run: cpthi74k, 0.3
# Data cached for run: 459yyzc5, 0.31
# Data cached for run: 0mvodcvl, 0.31
# Data cached for run: 9czmchob, 0.32
# Data cached for run: ns2obqf7, 0.32
# Data cached for run: 5exwwre9, 0.32
# Data cached for run: 83s1kzco, 0.33
# Data cached for run: urplit72, 0.33
# Data cached for run: 00arn9fy, 0.34
# Data cached for run: g11fvo1j, 0.34
# Data cached for run: ve6dy705, 0.35
# Data cached for run: dm5ohzir, 0.35
# Data cached for run: fhngka6c, 0.36
# Data cached for run: socnf4qj, 0.34
# Data cached for run: evabjz6p, 0.36
# Data cached for run: xb15mmgj, 0.37
# Data cached for run: tge0ogcp, 0.37
# Data cached for run: gbwtsx3d, 0.37
# Data cached for run: 3swt95sm, 0.38
# Data cached for run: t5x3uq0u, 0.38
# Data cached for run: l9p4xg7d, 0.39
# Data cached for run: rbsc35bf, 0.39
# Data cached for run: c8crgwti, 0.39
# Data cached for run: di9tl7yc, 0.4
# Data cached for run: 6ena0w2l, 0.42
# Data cached for run: bqdgm7gk, 0.4
# Data cached for run: xvjl36n2, 0.41
# Data cached for run: ik4qixtk, 0.41
# Data cached for run: 38srusyw, 0.42
# Data cached for run: ir4j4g7p, 0.43
# Data cached for run: do24i87j, 0.42
# Data cached for run: obmjlowl, 0.44
# Data cached for run: zauzqlgm, 0.43
# Data cached for run: jd7jgz7j, 0.45
# Data cached for run: vd9e7xb6, 0.44
# Data cached for run: vkcussj3, 0.45
# Data cached for run: h9tpftha, 0.45
# Data cached for run: u2cpcpf7, 0.46
# Data cached for run: 6nzw6gn1, 0.46
# Data cached for run: 0bmk93pf, 0.47
# Data cached for run: rwu6fky2, 0.47
# Data cached for run: m0e6xo0g, 0.47
# Data cached for run: r8jz6r2a, 0.48
# Data cached for run: z0zd9fkf, 0.48
# Data cached for run: xlyqkr1g, 0.49
# Data cached for run: hkt2epus, 0.5
# Data cached for run: x6kdgi6t, 0.5
# Data cached for run: f517nzqz, 0.49
# Data cached for run: 474znfj2, 0.51
# Data cached for run: 3o2fmkvr, 0.51
# Data cached for run: iqwdmrkd, 0.52
# Data cached for run: nb62e242, 0.5
# Data cached for run: pv1j9gpd, 0.52
# Data cached for run: leehsexb, 0.53
# Data cached for run: 0cjioni7, 0.53
# Data cached for run: 1s89xbgz, 0.54
# Data cached for run: 3u4jbufb, 0.53
# Data cached for run: nucp13hp, 0.55
# Data cached for run: p3vrb51k, 0.55
# Data cached for run: twwvb3be, 0.54
# Data cached for run: n4qqgz7c, 0.55
# Data cached for run: vyvfwcgz, 0.57
# Data cached for run: 1qa87kdu, 0.57
# Data cached for run: fv99ilyg, 0.56
# Data cached for run: ngxsvgnq, 0.56
# Data cached for run: m4z9waxb, 0.58
# Data cached for run: 76jf80zw, 0.59
# Data cached for run: phaftru0, 0.58
# Data cached for run: k10m3g2i, 0.58
# Data cached for run: zjxgqej8, 0.61
# Data cached for run: n4h8ml95, 0.62
# Data cached for run: qvb0tn4w, 0.59
# Data cached for run: mbk8jg6o, 0.6
# Data cached for run: 1o22u4ci, 0.63
# Data cached for run: 2n8ectp5, 0.61
# Data cached for run: tr7bhdmj, 0.63
# Data cached for run: qekz68at, 0.6
# Data cached for run: 6f2z8vz2, 0.64
# Data cached for run: 4fuo8nss, 0.63
# Data cached for run: kmn6zxe7, 0.61
# Data cached for run: 8mpytd27, 0.64
# Data cached for run: kf235dn4, 0.65
# Data cached for run: ecyl97v6, 0.62
# Data cached for run: 4qsqvbl1, 0.65
# Data cached for run: kxsl9a79, 0.66
# Data cached for run: ax4g0a5x, 0.66
# Data cached for run: 8zbsvm39, 0.66
# Data cached for run: y36gd3dh, 0.67
# Data cached for run: 5k871w9y, 0.68
# Data cached for run: 6vjnyh7w, 0.68
# Data cached for run: w287c0mr, 0.67
# Data cached for run: yvnm9w38, 0.68
# Data cached for run: 4b02lkag, 0.69
# Data cached for run: 1rxgwz1c, 0.69
# Data cached for run: 8k0rogr7, 0.7
# Data cached for run: bhvef6m0, 0.71
# Data cached for run: xz1fx8t0, 0.71
# Data cached for run: 4plowobv, 0.7
# Data cached for run: jgejbpxp, 0.71
# Data cached for run: kw6ol315, 0.72
# Data cached for run: 5jq7bx3b, 0.73
# Data cached for run: d6lecizp, 0.73
# Data cached for run: qr61mo0o, 0.72
# Data cached for run: sm0m1nbk, 0.74
# Data cached for run: j4gnddjk, 0.75
# Data cached for run: qcvyxpdo, 0.74
# Data cached for run: na5or2s1, 0.76
# Data cached for run: d1xwaxfg, 0.74
# Data cached for run: 7ax7c2z9, 0.76
# Data cached for run: ugtvpitr, 0.76
# Data cached for run: bqa9ci94, 0.77
# Data cached for run: li88lf74, 0.75
# Data cached for run: k7jh8qq4, 0.0
# Data cached for run: 1dy703wo, 0.005
# Data cached for run: ftdn9pmm, 0.035
# Data cached for run: vjha304l, 0.03
# Data cached for run: falk4gza, 0.02
# Data cached for run: 6s6dw3hh, 0.04
# Data cached for run: swkdma3s, 0.015
# Data cached for run: scuuseyc, 0.025
# Data cached for run: qtla80ds, 0.0099
# Data cached for run: i9zf4n7s, 0.045
# Data cached for run: 0exfwsvf, 0.054
# Data cached for run: nzuia92g, 0.069
# Data cached for run: nt0b01ap, 0.059
# Data cached for run: daybk1q9, 0.05
# Data cached for run: 6196yrxe, 0.079
# Data cached for run: 87zi5ir3, 0.064
# Data cached for run: jka0ng31, 0.074
# Data cached for run: lthm593i, 0.084
# Data cached for run: 7jz21j1u, 0.099
# Data cached for run: fh9mgdt0, 0.089
# Data cached for run: olditqpa, 0.094
# Data cached for run: 86ett0k9, 0.11
# Data cached for run: b4v09oc8, 0.12
# Data cached for run: gee383yu, 0.11
# Data cached for run: ytuqic4q, 0.1
# Data cached for run: f5tqp3ft, 0.14
# Data cached for run: ergqj02u, 0.12
# Data cached for run: 2ctiiq5h, 0.15
# Data cached for run: zycl6rjg, 0.13
# Data cached for run: pnggh4hm, 0.14
# Data cached for run: b3d6kc4w, 0.15
# Data cached for run: lc48yqcb, 0.13
# Data cached for run: g0fb3zog, 0.17
# Data cached for run: 95sfcrdz, 0.16
# Data cached for run: qeoswy00, 0.16
# Data cached for run: zz0gm29w, 0.17
# Data cached for run: 2mse8y8f, 0.18
# Data cached for run: k09srooa, 0.19
# Data cached for run: mwda89kk, 0.18
# Data cached for run: 9ixqm0ks, 0.19
# Data cached for run: kilpvkc4, 0.2
# Data cached for run: lz96qlp4, 0.21
# Data cached for run: pvgsq6d2, 0.2
# Data cached for run: 54krtf1f, 0.22
# Data cached for run: g37vvq0t, 0.23
# Data cached for run: 4che9f6r, 0.22
# Data cached for run: x00v2e2i, 0.21
# Data cached for run: ffc3lcu2, 0.23
# Data cached for run: 07rxca2r, 0.24
# Data cached for run: o6q5x4zm, 0.25
# Data cached for run: 6qr68wfp, 0.25
# Data cached for run: u1okfc9k, 0.26
# Data cached for run: sp9ofmjo, 0.24
# Data cached for run: fkhn8x9p, 0.26
# Data cached for run: rwcor52p, 0.27
# Data cached for run: qiri1wz4, 0.28
# Data cached for run: bnh7s77o, 0.27
# Data cached for run: ixyl1yc2, 0.28
# Data cached for run: g2yxn2uw, 0.29
# Data cached for run: mzxdssye, 0.3
# Data cached for run: 5winbmmk, 0.29
# Data cached for run: 3gtspd01, 0.31
# Data cached for run: fgicnsb8, 0.31
# Data cached for run: ss3h1pcy, 0.3
# Data cached for run: 0cahg3kj, 0.32
# Data cached for run: 75mat1n7, 0.32
# Data cached for run: vmrfire7, 0.33
# Data cached for run: 1vkfwmmr, 0.34
# Data cached for run: oitqglqa, 0.33
# Data cached for run: 7r442jac, 0.35
# Data cached for run: 936qii9x, 0.35
# Data cached for run: h5wix5vw, 0.34
# Data cached for run: 52zht0tt, 0.37
# Data cached for run: sh9ej599, 0.36
# Data cached for run: ng26nc33, 0.37
# Data cached for run: s95zdbxj, 0.38
# Data cached for run: tz8z173w, 0.36
# Data cached for run: svf3iu2e, 0.39
# Data cached for run: t4t0si9a, 0.38
# Data cached for run: ky61tgys, 0.39
# Data cached for run: x98mtl3l, 0.4
# Data cached for run: j3wx1bpa, 0.4Data cached for run: cjdue1q4, 0.41
#
# Data cached for run: mjwrd0a0, 0.42
# Data cached for run: e0g4ievj, 0.43
# Data cached for run: ne6u3nfu, 0.42
# Data cached for run: kdh7k1sj, 0.43
# Data cached for run: 4yx45vy9, 0.41
# Data cached for run: 9x2awf64, 0.44
# Data cached for run: rk1fbctm, 0.46
# Data cached for run: 4l6qz7rl, 0.45
# Data cached for run: 8lw441q4, 0.45
# Data cached for run: 96b7h5d8, 0.44
# Data cached for run: qn56zwn2, 0.46
# Data cached for run: fr1me7wv, 0.47
# Data cached for run: jmy5qx91, 0.47
# Data cached for run: gfdj7qdw, 0.48
# Data cached for run: jr70jlvu, 0.49
# Data cached for run: 64s3h8y5, 0.49
# Data cached for run: qnoue7ir, 0.5
# Data cached for run: bk55qqc1, 0.48
# Data cached for run: wrunjab7, 0.5
# Data cached for run: 4j7w0c7h, 0.5
# Data cached for run: d06cl1b7, 0.51
# Data cached for run: 258qxvu0, 0.52
# Data cached for run: um6otc12, 0.51
# Data cached for run: h6wdyitf, 0.52
# Data cached for run: bw0n02w3, 0.53
# Data cached for run: gl1911j4, 0.53
# Data cached for run: dilcfg90, 0.54
# Data cached for run: zb4ohij8, 0.55
# Data cached for run: vwduerqj, 0.55
# Data cached for run: 70dn3lsp, 0.57
# Data cached for run: oksz6huh, 0.56
# Data cached for run: e5gsv86h, 0.56
# Data cached for run: 6vj1pams, 0.54
# Data cached for run: 38ggvn5j, 0.57
# Data cached for run: r4nextzv, 0.58
# Data cached for run: t9vx723j, 0.59
# Data cached for run: 9vj4rw9a, 0.58
# Data cached for run: le14da6w, 0.6
# Data cached for run: 7ysf8u96, 0.59
# Data cached for run: 891rw9s8, 0.6
# Data cached for run: f60ar1ov, 0.61
# Data cached for run: 7o09k61g, 0.63
# Data cached for run: q5pdzj0x, 0.61
# Data cached for run: 6z3w2lk7, 0.62
# Data cached for run: rn3u4j2b, 0.64
# Data cached for run: dep8l9cp, 0.63
# Data cached for run: cqj1fg90, 0.62
# Data cached for run: 9yyt9qmg, 0.65
# Data cached for run: djmwoeau, 0.66
# Data cached for run: jvtj91oo, 0.64
# Data cached for run: 4oa4zu1a, 0.65
# Data cached for run: a4mn8e66, 0.66
# Data cached for run: grfaxonf, 0.67
# Data cached for run: 428kwl8t, 0.67
# Data cached for run: pqx3ofi3, 0.68
# Data cached for run: s6sq9r7a, 0.69
# Data cached for run: kjpos7ho, 0.68
# Data cached for run: tzdupmoa, 0.7
# Data cached for run: riwadfjr, 0.69
# Data cached for run: t94am10x, 0.71
# Data cached for run: qj0x775x, 0.73
# Data cached for run: bat4hduw, 0.71
# Data cached for run: dnwphf8a, 0.7
# Data cached for run: jjk7sauh, 0.72
# Data cached for run: hgiwyktz, 0.72

# %%
len(runs)
# Out:
# 202

# %%
from collections import defaultdict
data = defaultdict(dict)

for project_name in PROJECTS:
    api = wandb.Api(timeout=20)
    runs = api.runs(f"{entity_name}/{project_name}")
    data[project_name] = defaultdict(list)
    for run in runs:
        cache_path = os.path.join(cache_dir, f"{run.id}.pkl")
        if run.state != "finished":
            # print(cache_path)
            continue
            
        config = {k:v.get('value') for k, v in json.loads(run.json_config).items()}
    
        if config.get('async_datarate') is None:
            continue
    
        if os.path.exists(cache_path):
            run_df = pd.read_pickle(cache_path)
        else:
            run_df = run.history()
            run_df.to_pickle(cache_path)
    
        df = run_df[['charts/episodic_return']]
    
        dic = dict(df[~df['charts/episodic_return'].isnull()].mean())
    
        data[project_name][config.get('async_datarate')].append(dic.get('charts/episodic_return'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 25
#      22     run_df = run.history()
#      23     run_df.to_pickle(cache_path)
# ---> 25 df = run_df[['charts/episodic_return']]
#      27 dic = dict(df[~df['charts/episodic_return'].isnull()].mean())
#      29 data[project_name][config.get('async_datarate')].append(dic.get('charts/episodic_return'))
#
# File ~/Library/Caches/pypoetry/virtualenvs/async-mdp-PGRAS291-py3.10/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Library/Caches/pypoetry/virtualenvs/async-mdp-PGRAS291-py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/Library/Caches/pypoetry/virtualenvs/async-mdp-PGRAS291-py3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['charts/episodic_return'], dtype='object')] are in the [columns]"

# %%
data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
renamed_data = {
    "Cluster, DQN, lunarlander-v2": data["beluga_8cpu-testing-lunarlander-v2-300000"],
    "Cluster, DQN, acrobot-v1": data["beluga_8cpu-testing-acrobot-v1-300000"],
    "Cluster, DQN, mountaincar-v0": data["beluga_8cpu-testing-mountaincar-v0-300000"],
    "Cluster, DQN, cartpole-v1": data["beluga_8cpu-testing-cartpole-v1-300000"],
}

# {
#     "beluga dqn acrobot-v0": data['beluga_4cpu_perf_arrayjob-simplified-async-interface-with-dqn-acrobot-v1-None'],
#     "beluga dqn cartpole-v1": data['beluga_4cpu_perf_arrayjob-simplified-async-interface-with-dqn-mountaincar-v0-None'],
#     "beluga dqn cartpole-v1": data['beluga_4cpu_perf_arrayjob-simplified-async-interface-with-dqn-cartpole-v1-None'],
#     "m1 dqn cartpole-v1": data['m1_mac-simplified-async-interface-with-dqn-cartpole-v1-None'],
# }

# %%
import numpy as np
import math
for project_name, project_data in renamed_data.items():
    # Convert the data into a DataFrame suitable for Seaborn
    data_points = []
    seed_count = []
    for step_rate, values in project_data.items():
        seed_count.append(len(values))
        for value in values:
            data_points.append({"Environment Step Rate": step_rate, "Mean Episodic Return": value})
    
    df = pd.DataFrame(data_points)
    
    fig, ax = plt.subplots(figsize=(10, 6))
    sns.lineplot(x="Environment Step Rate", y="Mean Episodic Return", data=df, errorbar=('ci', 95), ax=ax)
    ax.set_title(project_name + f" performance by environment step rate, seeds={math.floor(np.array(seed_count).mean())}")
    ax.set_xlabel("Environment Step Rate")
    ax.set_ylabel("Mean Episodic Return")
    labels = sorted(df['Environment Step Rate'].unique())
    ax.set_xticks(labels, rotation=45, ha='right', rotation_mode='anchor')
    ax.grid(True)
    
    fig.savefig(f'performance_by_steprate_{project_name.replace(", ","")}.svg', format="svg")
